# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.set_index('EmployeeNumber')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#df.corr(min_periods=3)

# Assuming df is your original DataFrame
df_encoded = pd.get_dummies(df, columns=['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime'])

# Now, df_encoded contains only numeric columns, and you can calculate correlations
correlation_matrix = df_encoded.corr(min_periods=3)
print(correlation_matrix)
# Out:
#                                         Age  DailyRate  DistanceFromHome  \
# Age                                1.000000   0.010661         -0.001686
# DailyRate                          0.010661   1.000000         -0.004985
# DistanceFromHome                  -0.001686  -0.004985          1.000000
# Education                          0.208034  -0.016806          0.021042
# EmployeeCount                           NaN        NaN               NaN
# EmployeeNumber                    -0.010145  -0.050990          0.032916
# EnvironmentSatisfaction            0.010146   0.018355         -0.016075
# HourlyRate                         0.024287   0.023381          0.031131
# JobInvolvement                     0.029820   0.046135          0.008783
# JobLevel                           0.509604   0.002966          0.005303
# JobSatisfaction                   -0.004892   0.030571         -0.003669
# MonthlyIncome                      0.497855   0.007707         -0.017014
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_2 = pd.DataFrame()
df_2 = df._drop_axis(['Attrition', 'EmployeeCount', 'Over18', 'StandardHours'], axis=1)
#df_2.set_index('EmployeeNumber', inplace=True)
df_2.head(10)
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
# 5   32  Travel_Frequently       1005  Research & Development
# 6   59      Travel_Rarely       1324  Research & Development
# 7   30      Travel_Rarely       1358  Research & Development
# 8   38  Travel_Frequently        216  Research & Development
# 9   36      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# ...

# %%
df_2.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df_2 = df_2.rename(columns={'Age': 'Emp_age', 'BusinessTravel': 'Biz_Travel' , 'DailyRate': 'Daily_R', 'Department' : 'Dept', 'DistanceFromHome' : 'Dist_from_home', 'Education' : 'Edu', 'EducationField' : 'Edu_Field', 'EmployeeNumber' : 'Emp_no', 'EnvironmentSatisfaction' : 'Env_Sat' , 'Gender' : 'Gender', 'HourlyRate' : 'Hour_Rat', 'JobInvolvement' : 'Job_Invol' , 'JobLevel' : 'Job_L' , 'JobRole' : 'JobRol', 'JobSatisfaction' : 'Job_Sat', 'MaritalStatus' : 'Marital_Status', 'MonthlyIncome' : 'Mon_Income', 'MonthlyRate' : 'Mon_Rate', 'NumCompaniesWorked' : 'Num_Comp_Worked', 'OverTime' : 'Over_Time', 'PercentSalaryHike' : 'Percent_Sal_Hike' , 'PerformanceRating' : 'Perfor_Rat', 'RelationshipSatisfaction' : 'Relat_Sat', 'StockOptionLevel' : 'Stock_Opt_Le', 'TotalWorkingYears' : 'Total_Wo_Y', 'TrainingTimesLastYear' : 'Training_TimesLast_Y', 'WorkLifeBalance' : 'Wo_Life_Bal', 'YearsAtCompany' : 'Y_At_Com' , 'YearsInCurrentRole' : 'Y_InCur_Role', 'YearsSinceLastPromotion' : 'Y_SinceLast_Promo', 'YearsWithCurrManager' : 'Y_W_Curr_Mang'})
df_2.head()
# Out:
#    Emp_age         Biz_Travel  Daily_R                    Dept  \
# 0       41      Travel_Rarely     1102                   Sales
# 1       49  Travel_Frequently      279  Research & Development
# 2       37      Travel_Rarely     1373  Research & Development
# 3       33  Travel_Frequently     1392  Research & Development
# 4       27      Travel_Rarely      591  Research & Development
#
#    Dist_from_home  Edu      Edu_Field  Emp_no  Env_Sat  Gender  ...  \
# 0               1    2  Life Sciences       1        2  Female  ...
# 1               8    1  Life Sciences       2        3    Male  ...
# 2               2    2          Other       4        4    Male  ...
# 3               3    4  Life Sciences       5        4  Female  ...
# 4               2    1        Medical       7        1    Male  ...
#
#    Perfor_Rat  Relat_Sat  Stock_Opt_Le Total_Wo_Y  Training_TimesLast_Y  \
# 0           3          1             0          8                     0
# ...

# %%
df_2.drop_duplicates(inplace=True)
df_2
# Out:
#       Emp_age         Biz_Travel  Daily_R                    Dept  \
# 0          41      Travel_Rarely     1102                   Sales
# 1          49  Travel_Frequently      279  Research & Development
# 2          37      Travel_Rarely     1373  Research & Development
# 3          33  Travel_Frequently     1392  Research & Development
# 4          27      Travel_Rarely      591  Research & Development
# ...       ...                ...      ...                     ...
# 1465       36  Travel_Frequently      884  Research & Development
# 1466       39      Travel_Rarely      613  Research & Development
# 1467       27      Travel_Rarely      155  Research & Development
# 1468       49  Travel_Frequently     1023                   Sales
# 1469       34      Travel_Rarely      628  Research & Development
#
#       Dist_from_home  Edu      Edu_Field  Emp_no  Env_Sat  Gender  ...  \
# 0                  1    2  Life Sciences       1        2  Female  ...
# ...

# %%
df_2[df_2.duplicated()].count()
# Out:
# Emp_age                 0
# Biz_Travel              0
# Daily_R                 0
# Dept                    0
# Dist_from_home          0
# Edu                     0
# Edu_Field               0
# Emp_no                  0
# Env_Sat                 0
# Gender                  0
# Hour_Rat                0
# Job_Invol               0
# Job_L                   0
# JobRol                  0
# Job_Sat                 0
# Marital_Status          0
# Mon_Income              0
# Mon_Rate                0
# Num_Comp_Worked         0
# Over_Time               0
# Percent_Sal_Hike        0
# Perfor_Rat              0
# Relat_Sat               0
# Stock_Opt_Le            0
# Total_Wo_Y              0
# Training_TimesLast_Y    0
# Wo_Life_Bal             0
# Y_At_Com                0
# Y_InCur_Role            0
# Y_SinceLast_Promo       0
# Y_W_Curr_Mang           0
# dtype: int64

# %%
#df_2.corr(min_periods=3).style.background_gradient(cmap='Greens')

# %% [raw]
# df_2.isna().sum()

# %%
df_2.describe()
# Out:
#            Emp_age      Daily_R  Dist_from_home          Edu       Emp_no  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810   802.485714        9.192517     2.912925  1024.865306
# std       9.135373   403.509100        8.106864     1.024165   602.024335
# min      18.000000   102.000000        1.000000     1.000000     1.000000
# 25%      30.000000   465.000000        2.000000     2.000000   491.250000
# 50%      36.000000   802.000000        7.000000     3.000000  1020.500000
# 75%      43.000000  1157.000000       14.000000     4.000000  1555.750000
# max      60.000000  1499.000000       29.000000     5.000000  2068.000000
#
#            Env_Sat     Hour_Rat    Job_Invol        Job_L      Job_Sat  ...  \
# count  1470.000000  1470.000000  1470.000000  1470.000000  1470.000000  ...
# mean      2.721769    65.891156     2.729932     2.063946     2.728571  ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df_2 is your DataFrame
plt.figure(figsize=(15, 10))  # Set the size of the heatmap

# Convert categorical columns to numerical using one-hot encoding (get_dummies)
categorical_columns = ['Biz_Travel', 'Dept', 'Edu_Field', 'Gender', 'JobRol', 'Marital_Status', 'Over_Time']
df_encoded = pd.get_dummies(df_2, columns=categorical_columns)

# Calculate the correlation matrix
corr_col = df_encoded.corr().round(2)

# Create a heatmap
sns.heatmap(data=corr_col, center=0, vmin=-1, vmax=1, annot=True, cmap='Blues')

# Add labels, titles, etc. as needed
plt.title('Correlation Heatmap')
plt.show()

# %%
df_2.columns
# Out:
# Index(['Emp_age', 'Biz_Travel', 'Daily_R', 'Dept', 'Dist_from_home', 'Edu',
#        'Edu_Field', 'Emp_no', 'Env_Sat', 'Gender', 'Hour_Rat', 'Job_Invol',
#        'Job_L', 'JobRol', 'Job_Sat', 'Marital_Status', 'Mon_Income',
#        'Mon_Rate', 'Num_Comp_Worked', 'Over_Time', 'Percent_Sal_Hike',
#        'Perfor_Rat', 'Relat_Sat', 'Stock_Opt_Le', 'Total_Wo_Y',
#        'Training_TimesLast_Y', 'Wo_Life_Bal', 'Y_At_Com', 'Y_InCur_Role',
#        'Y_SinceLast_Promo', 'Y_W_Curr_Mang'],
#       dtype='object')

# %%
df_2.info()
df_4=df_2.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Emp_age               1470 non-null   int64
#  1   Biz_Travel            1470 non-null   object
#  2   Daily_R               1470 non-null   int64
#  3   Dept                  1470 non-null   object
#  4   Dist_from_home        1470 non-null   int64
#  5   Edu                   1470 non-null   int64
#  6   Edu_Field             1470 non-null   object
#  7   Emp_no                1470 non-null   int64
#  8   Env_Sat               1470 non-null   int64
#  9   Gender                1470 non-null   object
#  10  Hour_Rat              1470 non-null   int64
#  11  Job_Invol             1470 non-null   int64
#  12  Job_L                 1470 non-null   int64
#  13  JobRol                1470 non-null   object
#  14  Job_Sat               1470 non-null   int64
# ...

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Emp_age               1470 non-null   int64
#  1   Biz_Travel            1470 non-null   object
#  2   Daily_R               1470 non-null   int64
#  3   Dept                  1470 non-null   object
#  4   Dist_from_home        1470 non-null   int64
#  5   Edu                   1470 non-null   int64
#  6   Edu_Field             1470 non-null   object
#  7   Emp_no                1470 non-null   int64
#  8   Env_Sat               1470 non-null   int64
#  9   Gender                1470 non-null   object
#  10  Hour_Rat              1470 non-null   int64
#  11  Job_Invol             1470 non-null   int64
#  12  Job_L                 1470 non-null   int64
#  13  JobRol                1470 non-null   object
#  14  Job_Sat               1470 non-null   int64
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df_2 ,hue="Over_Time", x="Dept", y="Hour_Rat", palette="icefire", width=0.4, ci=None)
# Out:
# <Axes: xlabel='Dept', ylabel='Hour_Rat'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df_2 ,hue="Marital_Status", x="Dept", y="Emp_no", palette="YlGnBu", width=0.4, ci=None)
# Out:
# <Axes: xlabel='Dept', ylabel='Emp_no'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Sample DataFrame
data = {
    'Gender': ['Male', 'Female', 'Male', 'Male', 'Female'],
    # Add more data as needed
}

df_2 = pd.DataFrame(data)

# Count the occurrences of each gender
gender_count = df_2['Gender'].value_counts()

# Define labels and colors
labels = gender_count.index
colors = sns.color_palette("crest")

# Create a pie chart
plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(gender_count, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')

# Show the pie chart
plt.show()

# %%
df_4.columns
# Out:
# Index(['Emp_age', 'Biz_Travel', 'Daily_R', 'Dept', 'Dist_from_home', 'Edu',
#        'Edu_Field', 'Emp_no', 'Env_Sat', 'Gender', 'Hour_Rat', 'Job_Invol',
#        'Job_L', 'JobRol', 'Job_Sat', 'Marital_Status', 'Mon_Income',
#        'Mon_Rate', 'Num_Comp_Worked', 'Over_Time', 'Percent_Sal_Hike',
#        'Perfor_Rat', 'Relat_Sat', 'Stock_Opt_Le', 'Total_Wo_Y',
#        'Training_TimesLast_Y', 'Wo_Life_Bal', 'Y_At_Com', 'Y_InCur_Role',
#        'Y_SinceLast_Promo', 'Y_W_Curr_Mang'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(20, 5))

# Create a box plot with Seaborn
sns.boxplot(data=df_4, x="Edu_Field", y="Edu", hue='Edu_Field', width=0.8, showmeans=True, 
            meanprops={"marker": "o", "markerfacecolor": "white", "markeredgecolor": "black"})

# Add labels and title
plt.xlabel("Education Field")
plt.ylabel("Education Level")
plt.title("Box Plot of Education Level by Education Field")

# Show the plot
plt.show()

# %%
df_Employee = df[['EmployeeNumber', 'Department' , 'JobRole' ,'Education' , 'MonthlyIncome']]
df_Employee.head()
# Out:
#    EmployeeNumber              Department                JobRole  Education  \
# 0               1                   Sales        Sales Executive          2
# 1               2  Research & Development     Research Scientist          1
# 2               4  Research & Development  Laboratory Technician          2
# 3               5  Research & Development     Research Scientist          4
# 4               7  Research & Development  Laboratory Technician          1
#
#    MonthlyIncome
# 0           5993
# 1           5130
# 2           2090
# 3           2909
# 4           3468

# %%
df_2.columns
# Out:
# Index(['Gender'], dtype='object')

# %%
df_Employee[df_Employee['MonthlyIncome']>3000].head(10)
# Out:
#     EmployeeNumber              Department                    JobRole  \
# 0                1                   Sales            Sales Executive
# 1                2  Research & Development         Research Scientist
# 4                7  Research & Development      Laboratory Technician
# 5                8  Research & Development      Laboratory Technician
# 8               12  Research & Development     Manufacturing Director
# 9               13  Research & Development  Healthcare Representative
# 11              15  Research & Development      Laboratory Technician
# 15              20  Research & Development     Manufacturing Director
# 16              21  Research & Development         Research Scientist
# 18              23                   Sales                    Manager
#
#     Education  MonthlyIncome
# 0           2           5993
# 1           1           5130
# 4           1           3468
# 5           2           3068
# 8           3           9526
# ...

# %%
df_Employee[df_Employee['Education']>1]
# Out:
#       EmployeeNumber              Department                 JobRole  \
# 0                  1                   Sales         Sales Executive
# 2                  4  Research & Development   Laboratory Technician
# 3                  5  Research & Development      Research Scientist
# 5                  8  Research & Development   Laboratory Technician
# 6                 10  Research & Development   Laboratory Technician
# ...              ...                     ...                     ...
# 1464            2060                   Sales    Sales Representative
# 1465            2061  Research & Development   Laboratory Technician
# 1467            2064  Research & Development  Manufacturing Director
# 1468            2065                   Sales         Sales Executive
# 1469            2068  Research & Development   Laboratory Technician
#
#       Education  MonthlyIncome
# 0             2           5993
# 2             2           2090
# 3             4           2909
# ...

# %%
f,axes = plt.subplots(2,2, figsize=(15,15))
sns.set_style("darkgrid")
fig1 = sns.barplot(data = df_Employee ,x = 'Department', y = 'Education', ax = axes[0,0] )
fig2 = sns.barplot(data = df_Employee[df_Employee['Education']>1] ,x = 'JobRole', y = 'Education', ax = axes[0,1] )
fig3 = sns.barplot(data = df_Employee[df_Employee['MonthlyIncome']>3000] ,x = 'JobRole', y = 'MonthlyIncome', ax = axes[1,0] )
fig4 = sns.barplot(data = df_Employee[df_Employee['Education']>2] ,x = 'Education', y = 'MonthlyIncome', ax = axes[1,1] )
fig2.set_xticklabels(fig2.get_xticklabels(), rotation=45)
fig3.set_xticklabels(fig3.get_xticklabels(), rotation=45)
plt.show()

# %%
#df_dept = df.groupby('Department', as_index=False).agg({'Education':'sum' , 'MonthlyIncome':'sum'})

#df_dept.head()
